# %%
import os
a, _ =os.path.split('../data/fma_small/000/000141.mp3')
os.path.split(a)
# Out:
# ('../data/fma_small', '000')

# %%
# Out:
# 2.0

# %%
import pathlib
# Out:
# ['../data/fma_small/093/093519.mp3',
#  '../data/fma_small/093/093940.mp3',
#  '../data/fma_small/093/093363.mp3',
#  '../data/fma_small/093/093364.mp3',
#  '../data/fma_small/093/093074.mp3',
#  '../data/fma_small/093/093921.mp3',
#  '../data/fma_small/093/093522.mp3',
#  '../data/fma_small/093/093941.mp3',
#  '../data/fma_small/093/093920.mp3',
#  '../data/fma_small/093/093712.mp3',
#  '../data/fma_small/093/093076.mp3',
#  '../data/fma_small/093/093918.mp3',
#  '../data/fma_small/093/093956.mp3',
#  '../data/fma_small/093/093917.mp3',
#  '../data/fma_small/093/093919.mp3',
#  '../data/fma_small/093/093950.mp3',
#  '../data/fma_small/093/093075.mp3',
#  '../data/fma_small/093/093985.mp3',
#  '../data/fma_small/093/093523.mp3',
#  '../data/fma_small/093/093868.mp3',
#  '../data/fma_small/093/093942.mp3',
#  '../data/fma_small/093/093943.mp3',
#  '../data/fma_small/093/093981.mp3',
#  '../data/fma_small/093/093986.mp3',
#  '../data/fma_small/093/093518.mp3',
# ...
